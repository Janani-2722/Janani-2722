# %% [markdown]
# <a href="https://colab.research.google.com/github/Janani-2722/Janani-2722/blob/main/data_analytics_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/content/indian_food.csv')
data
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
data.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian       45.0       25.0          sweet  dessert    West Bengal
# ...

# %%
data.tail()
# Out:
#           name                                        ingredients        diet  \
# 250  Til Pitha            Glutinous rice, black sesame seeds, gur  vegetarian
# 251    Bebinca  Coconut milk, egg yolks, clarified butter, all...  vegetarian
# 252     Shufta  Cottage cheese, dry dates, dried rose petals, ...  vegetarian
# 253  Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...  vegetarian
# 254     Pinaca  Brown rice, fennel seeds, grated coconut, blac...  vegetarian
#
#      prep_time  cook_time flavor_profile   course            state      region
# 250          5         30          sweet  dessert            Assam  North East
# 251         20         60          sweet  dessert              Goa        West
# 252         -1         -1          sweet  dessert  Jammu & Kashmir       North
# 253         20         45          sweet  dessert   Madhya Pradesh     Central
# 254         -1         -1          sweet  dessert              Goa        West

# %%
data.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
data.isnull().any()
# Out:
# name              False
# ingredients       False
# diet              False
# prep_time         False
# cook_time         False
# flavor_profile    False
# course            False
# state             False
# region             True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
data=data.replace(-1,np.nan)
data=data.replace('-1',np.nan)
data.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian       45.0       25.0          sweet  dessert    West Bengal
# ...

# %%
data.isnull().any()
# Out:
# name              False
# ingredients       False
# diet              False
# prep_time          True
# cook_time          True
# flavor_profile     True
# course            False
# state              True
# region             True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# name               0
# ingredients        0
# diet               0
# prep_time         30
# cook_time         28
# flavor_profile    29
# course             0
# state             24
# region            14
# dtype: int64

# %%
data.shape
# Out:
# (255, 9)

# %%
import plotly.express as px
pie_data=data.diet.value_counts().reset_index()
pie_data
# Out:
#             index  diet
# 0      vegetarian   226
# 1  non vegetarian    29

# %%
pie_data.columns=['diet','count']
figure=px.pie(pie_data,names='diet',values='count',title='proportion of vegetarian & non-vegetarian',color_discrete_sequence=['blue', 'yellow'])
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/content/indian_food.csv')
data
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
data=data.replace(-1,np.nan)
data=data.replace('-1',np.nan)
data.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian       45.0       25.0          sweet  dessert    West Bengal
# ...

# %%
sweet_data=data[data['flavor_profile']=='sweet']
final_sweet_data=sweet_data[sweet_data['course']!='dessert']
final_sweet_data
# Out:
#                    name                                        ingredients  \
# 46       Obbattu holige  Maida flour, turmeric, coconut, chickpeas, jag...
# 85         Dal makhani   Red kidney beans, urad dal, cream, garam masal...
# 243  Mishti Chholar Dal  Chana dal, fresh coconut, ginger, cinnamon, ra...
#
#            diet  prep_time  cook_time flavor_profile       course  \
# 46   vegetarian        180         60          sweet  main course
# 85   vegetarian         10         60          sweet  main course
# 243  vegetarian         10         30          sweet  main course
#
#            state region
# 46     Karnataka  South
# 85        Punjab  North
# 243  West Bengal   East

# %%
import plotly.express as px
flav_data = data.flavor_profile.value_counts().reset_index()
flav_data.columns = ['flavor_profile', 'prep_time']
fig = px.bar(flav_data,x='flavor_profile',y='prep_time',title='variety of item according to the flavour',
color_discrete_sequence=['yellow'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cooking_time=data[['cook_time','name']]
cooking_time.head(10)
# Out:
#    cook_time            name
# 0       25.0      Balu shahi
# 1       30.0          Boondi
# 2       60.0  Gajar ka halwa
# 3       30.0          Ghevar
# 4       40.0     Gulab jamun
# 5       50.0          Imarti
# 6       50.0          Jalebi
# 7       20.0      Kaju katli
# 8       30.0        Kalakand
# 9       40.0           Kheer

# %%
cooking_time=cooking_time.sort_values(['cook_time'],ascending=True)
ten_quickly_cook=cooking_time.head()

# %%
cook_data=ten_quickly_cook.cook_time.value_counts().reset_index()
cook_data.columns=['cook_time','name']
fig=px.bar(cook_data,x='cook_time',y='name',title='dishes based on cooking time',color_discrete_sequence=['blue'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %%
cooking_time_longest=cooking_time.sort_values(['cook_time'],ascending=False)
cook_time_longest=cooking_time_longest.head(5)

# %%
import matplotlib.pyplot as plt
x=cook_time_longest['name']
y=cook_time_longest['cook_time']
plt.plot(x,y)
plt.title='Based on the cooking time'
plt.show()
